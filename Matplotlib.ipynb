# %%
import matplotlib.pyplot as plt
#see the plot in jupyter notebook
# %matplotlib inline
from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs
from sklearn.datasets import make_gaussian_quantiles

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#functional
plt.plot(x,y)
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
plt.plot(x,y)
ax2 = fig.add_subplot(2,2,2)
plt.plot(x)
ax3 = fig.add_subplot(2,2,3)
plt.plot(np.random.randn(50).cumsum(), 'k--')
ax4 = fig.add_subplot(2,2,4)
plt.hist(np.random.randn(100),bins=20)
# Out:
# (array([ 1.,  2.,  3.,  2.,  7.,  7.,  9., 10., 11.,  5.,  9.,  8.,  7.,
#          6.,  6.,  4.,  2.,  0.,  0.,  1.]),
#  array([-2.38340679, -2.12511161, -1.86681643, -1.60852125, -1.35022607,
#         -1.09193089, -0.83363571, -0.57534053, -0.31704535, -0.05875016,
#          0.19954502,  0.4578402 ,  0.71613538,  0.97443056,  1.23272574,
#          1.49102092,  1.7493161 ,  2.00761128,  2.26590646,  2.52420165,
#          2.78249683]),
#  <a list of 20 Patch objects>)

# %%
#subplot

fig,ax = plt.subplots(nrows=1,ncols=2)

ax[0].plot(x,y)
ax[0].set_title('Left')
ax[0].set_ylabel('Y')
ax[0].plot(x**2)

ax[1].plot(y,x)
ax[1].set_title('Right')
plt.tight_layout()

# %%
#figure size
fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(6,3),dpi=100)
ax[0].scatter(x,y,label='x and y')
ax[0].set_title('Left')
ax[0].set_ylabel('Y')
ax[0].plot(x**2,label='x^2')
ax[0].legend(loc=0)

ax[1].plot(y,x,color='red',linewidth=2,alpha=0.5, linestyle='dashed', marker='o',
           markerfacecolor='yellow', markeredgewidth=2, markeredgecolor='purple')
ax[1].set_title('Right')

plt.tight_layout()

# %%
x_new = np.linspace(0,5,20)
y_new = np.linspace(6,10,20)

# %%
x_new
# Out:
# array([0.        , 0.26315789, 0.52631579, 0.78947368, 1.05263158,
#        1.31578947, 1.57894737, 1.84210526, 2.10526316, 2.36842105,
#        2.63157895, 2.89473684, 3.15789474, 3.42105263, 3.68421053,
#        3.94736842, 4.21052632, 4.47368421, 4.73684211, 5.        ])

# %%
y_new
# Out:
# array([ 6.        ,  6.21052632,  6.42105263,  6.63157895,  6.84210526,
#         7.05263158,  7.26315789,  7.47368421,  7.68421053,  7.89473684,
#         8.10526316,  8.31578947,  8.52631579,  8.73684211,  8.94736842,
#         9.15789474,  9.36842105,  9.57894737,  9.78947368, 10.        ])

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(7,3),dpi=100)

X1, Y1 = make_blobs(n_features=2, centers=2)
ax[0].scatter(X1[:, 0], X1[:, 1], marker='o', c=Y1,
            s=25, edgecolor='k')
ax[0].set_ylabel('Feature 1')
ax[0].set_xlabel('Feature 2')
ax[1].scatter(X1[:, 0], X1[:, 1], marker='o', c=Y1,
            s=25, edgecolor='k')
plt.tight_layout()

# %%
#plt.title("One informative feature, one cluster per class", fontsize='small')
X1, Y1 = make_classification(n_features=2, n_redundant=0, n_informative=1,
                             n_clusters_per_class=1)
plt.scatter(X1[:, 0], X1[:, 1], marker='o', c=Y1,
            s=25, edgecolor='k')
