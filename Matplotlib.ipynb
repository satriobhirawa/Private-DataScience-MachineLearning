# %%
import matplotlib.pyplot as plt
#see the plot in jupyter notebook
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#functional
plt.plot(x,y)
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
plt.plot(x,y)
ax2 = fig.add_subplot(2,2,2)
plt.plot(x)
ax3 = fig.add_subplot(2,2,3)
plt.plot(np.random.randn(50).cumsum(), 'k--')
ax4 = fig.add_subplot(2,2,4)
plt.hist(np.random.randn(100),bins=20)
# Out:
# (array([ 4.,  1.,  2.,  8.,  5.,  6.,  9.,  7.,  8.,  6., 12.,  7.,  4.,
#          6.,  7.,  1.,  1.,  2.,  2.,  2.]),
#  array([-2.16493381, -1.92871263, -1.69249145, -1.45627027, -1.22004909,
#         -0.98382791, -0.74760673, -0.51138556, -0.27516438, -0.0389432 ,
#          0.19727798,  0.43349916,  0.66972034,  0.90594152,  1.1421627 ,
#          1.37838388,  1.61460506,  1.85082624,  2.08704742,  2.3232686 ,
#          2.55948978]),
#  <a list of 20 Patch objects>)

# %%
#subplot

fig,ax = plt.subplots(nrows=1,ncols=2)

ax[0].plot(x,y)
ax[0].set_title('Left')
ax[0].set_ylabel('Y')
ax[0].plot(x**2)

ax[1].plot(y,x)
ax[1].set_title('Right')
plt.tight_layout()

# %%
#figure size
fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(6,3),dpi=100)
ax[0].scatter(x,y,label='x and y')
ax[0].set_title('Left')
ax[0].set_ylabel('Y')
ax[0].plot(x**2,label='x^2')
ax[0].legend(loc=0)

ax[1].plot(y,x,color='red',linewidth=2,alpha=0.5, linestyle='dashed', marker='o',
           markerfacecolor='yellow', markeredgewidth=2, markeredgecolor='purple')
ax[1].set_title('Right')

plt.tight_layout()
